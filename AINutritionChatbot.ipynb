# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("food.csv")
df = data.drop(columns="Nutrient Data Bank Number" )
print(df.head())
print(df.info())
print(df.describe())
# Out:
#   Category                     Description  Data.Alpha Carotene  \
# 0     Milk                     Milk, human                    0
# 1     Milk                       Milk, NFS                    0
# 2     Milk                     Milk, whole                    0
# 3     Milk         Milk, low sodium, whole                    0
# 4     Milk  Milk, calcium fortified, whole                    0
#
#    Data.Beta Carotene  Data.Beta Cryptoxanthin  Data.Carbohydrate  \
# 0                   7                        0               6.89
# 1                   4                        0               4.87
# 2                   7                        0               4.67
# 3                   7                        0               4.46
# 4                   7                        0               4.67
#
#    Data.Cholesterol  Data.Choline  Data.Fiber  Data.Lutein and Zeaxanthin  \
# 0                14          16.0         0.0                           0
# ...

# %%
jsonFile = 'food.json'
df.to_json(jsonFile, orient= 'records')

# %%
from flask import Flask, jsonify
import json

# %%
with open('food.json' , 'r', encoding= 'utf-8') as file:
    data = json.load(file)
print(file)
# Out:
# <_io.TextIOWrapper name='food.json' mode='r' encoding='utf-8'>

# %%
import requests
import json
apiURL = "http://127.0.0.1:5000/recommend"
test_input = {
    "diet": "vegetarian",
    "vitamins": "Vitamin C",
    "minerals": "Iron",
    "protein": 15,   # Minimum protein requirement
    "carbs": 50,     # Max carbs allowed
    "fats": 20       # Max fats allowed
}
response = requests.post(apiURL , json=test_input)
print("Status Code:", response.status_code)
print("Response JSON:", response.json())
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# File /Applications/miniconda3/lib/python3.12/site-packages/urllib3/connection.py:203, in HTTPConnection._new_conn(self)
#     202 try:
# --> 203     sock = connection.create_connection(
#     204         (self._dns_host, self.port),
#     205         self.timeout,
#     206         source_address=self.source_address,
#     207         socket_options=self.socket_options,
#     208     )
#     209 except socket.gaierror as e:
#
# File /Applications/miniconda3/lib/python3.12/site-packages/urllib3/util/connection.py:85, in create_connection(address, timeout, source_address, socket_options)
#      84 try:
# ---> 85     raise err
#      86 finally:
#      87     # Break explicitly a reference cycle
#
# ...
