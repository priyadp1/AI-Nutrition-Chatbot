# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("food.csv")
df = data.drop(columns="Nutrient Data Bank Number" )
print(df.head())
print(df.info())
print(df.describe())
# Out:
#   Category                     Description  Data.Alpha Carotene  \
# 0     Milk                     Milk, human                    0
# 1     Milk                       Milk, NFS                    0
# 2     Milk                     Milk, whole                    0
# 3     Milk         Milk, low sodium, whole                    0
# 4     Milk  Milk, calcium fortified, whole                    0
#
#    Data.Beta Carotene  Data.Beta Cryptoxanthin  Data.Carbohydrate  \
# 0                   7                        0               6.89
# 1                   4                        0               4.87
# 2                   7                        0               4.67
# 3                   7                        0               4.46
# 4                   7                        0               4.67
#
#    Data.Cholesterol  Data.Choline  Data.Fiber  Data.Lutein and Zeaxanthin  \
# 0                14          16.0         0.0                           0
# ...

# %%
jsonFile = 'food.json'
df.to_json(jsonFile, orient= 'records')

# %%
from flask import Flask, jsonify
import json

# %%
with open('food.json' , 'r', encoding= 'utf-8') as file:
    data = json.load(file)
print(file)
# Out:
# <_io.TextIOWrapper name='food.json' mode='r' encoding='utf-8'>

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer

# ✅ Define model name and local save path
model_name = "gpt2"
local_path = "./models/gpt2"  # This is where we will save the model

# ✅ Download GPT-2 model and tokenizer
print("Downloading GPT-2 model... This may take a few minutes.")
model = AutoModelForCausalLM.from_pretrained(model_name)
tokenizer = AutoTokenizer.from_pretrained(model_name)

# ✅ Save model locally
model.save_pretrained(local_path)
tokenizer.save_pretrained(local_path)

print(f"✅ GPT-2 model downloaded and saved at: {local_path}")
# Out:
# ...
# ✅ GPT-2 model downloaded and saved at: ./models/gpt2

# %%
import os

local_path = "./models/gpt2"

if os.path.exists(local_path):
    print("✅ GPT-2 is downloaded at:", local_path)
else:
    print("❌ GPT-2 model not found!")
# Out:
# ✅ GPT-2 is downloaded at: ./models/gpt2

# %%
import requests
import json
apiURL = "http://127.0.0.1:5000/recommend"
food = input("Enter food name (or press Enter to skip): ") or None
vitamins = input("Enter required vitamins (comma-separated, or press Enter to skip): ")
minerals = input("Enter required minerals (comma-separated, or press Enter to skip): ")
vitamin_list = [v.strip() for v in vitamins.split(",")] if vitamins else []
mineral_list = [m.strip() for m in minerals.split(",")] if minerals else []
protein = float(input("Enter minimum protein (default 1.03): ") or 1.03)
carbs = float(input("Enter maximum carbs (default 6.89): ") or 6.89)
fats = float(input("Enter maximum fats (default 1.658): ") or 1.658)
testInput = {
    "food": food,
    "vitamins": vitamin_list,
    "minerals": mineral_list,
    "protein": protein,
    "carbs" : carbs,
    "fats" : fats
}
response = requests.post(apiURL, json=testInput)
print("\nStatus Code:", response.status_code)
try:
    print("Response JSON:", json.dumps(response.json(), indent=4))
except requests.exceptions.JSONDecodeError:
    print("Error: API returned invalid JSON. Check Flask logs.")
# Out:
# Status Code: 200
# Response JSON: {
#     "meals": [
#         {
#             "Category": "Yogurt",
#             "Data.Alpha Carotene": 0,
#             "Data.Beta Carotene": 6,
#             "Data.Beta Cryptoxanthin": 0,
#             "Data.Carbohydrate": 3.94,
#             "Data.Cholesterol": 10,
#             "Data.Choline": 15.2,
#             "Data.Fat.Monosaturated Fat": 0.486,
#             "Data.Fat.Polysaturated Fat": 0.076,
#             "Data.Fat.Saturated Fat": 1.23,
#             "Data.Fat.Total Lipid": 1.92,
#             "Data.Fiber": 0.0,
#             "Data.Lutein and Zeaxanthin": 1,
#             "Data.Lycopene": 0,
#             "Data.Major Minerals.Calcium": 115,
#             "Data.Major Minerals.Copper": 0.021,
#             "Data.Major Minerals.Iron": 0.04,
#             "Data.Major Minerals.Magnesium": 11,
#             "Data.Major Minerals.Phosphorus": 137,
#             "Data.Major Minerals.Potassium": 141,
#             "Data.Major Minerals.Sodium": 34,
# ...
